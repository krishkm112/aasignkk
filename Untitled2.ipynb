# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
ul=("https://www.flipkart.com/search?q=mi+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_5_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_5_sc_na_na&as-pos=2&as-type=RECENT&suggestionId=mi+mobiles%7CMobiles&requestId=782255ed-1fc5-463d-b3d0-25513e7f9562&as-backfill=on")

# %%
responce=requests.get(ul)

# %%
responce
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(responce.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
mobile=soup.select("._4rR01T")

# %%
mobile
# Out:
# [<div class="_4rR01T">Xiaomi 11i 5G (Stealth Black, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Slate grey, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Sea Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Slate Grey, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Starburst White, 64 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Space Black, 64 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Space Black, 64 GB)</div>,
#  <div class="_4rR01T">Redmi Note 11 (Horizon Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11T 5G (Stardust White, 128 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11T 5G (Stardust White, 128 GB)</div>,
#  <div class="_4rR01T">REDMI Note 11T 5G (Matte black, 128 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11Lite NE (Vinyl Black, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10A (Sea Blue, 64 GB)</div>,
# ...

# %%
price=soup.select("._1_WHN1")

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹26,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,647</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,679</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,781</div>,
#  <div class="_30jeq3 _1_WHN1">₹6,998</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,989</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,189</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,249</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,540</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,977</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,298</div>,
#  <div class="_30jeq3 _1_WHN1">₹24,379</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,623</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,356</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,765</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,900</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹20,795</div>,
# ...

# %%
rate=soup.select("._1lRcqv ._3LWZlK")

# %%
rate
# Out:
# [<div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
# ...

# %%
import pandas

# %%
mobiles=pandas.DataFrame(mobile,columns=["mobile name"])

# %%
mobiles["mobile price"]=price

# %%
mobiles["mobile rate"]=rate

# %%
mobiles
# Out:
#                                    mobile name mobile price mobile rate
# 0        Xiaomi 11i 5G (Stealth Black, 128 GB)    [₹26,999]   [4.2, []]
# 1                REDMI 10A (Slate grey, 64 GB)     [₹8,647]   [4.1, []]
# 2                  REDMI 10A (Sea Blue, 64 GB)     [₹8,679]   [4.1, []]
# 3                REDMI 10A (Slate Grey, 32 GB)     [₹7,781]   [4.1, []]
# 4         Redmi 9A Sport (Carbon Black, 32 GB)     [₹6,998]   [4.1, []]
# 5       Redmi Note 11 (Starburst White, 64 GB)    [₹13,989]   [4.2, []]
# 6           Redmi Note 11 (Space Black, 64 GB)    [₹13,189]   [4.2, []]
# 7           Redmi Note 11 (Space Black, 64 GB)    [₹13,990]   [4.2, []]
# 8          Redmi Note 11 (Horizon Blue, 64 GB)    [₹14,249]   [4.2, []]
# 9   REDMI Note 11T 5G (Stardust White, 128 GB)    [₹19,540]   [4.3, []]
# 10  REDMI Note 11T 5G (Stardust White, 128 GB)    [₹17,977]   [4.2, []]
# 11     REDMI Note 11T 5G (Matte black, 128 GB)    [₹19,298]   [4.2, []]
# ...
