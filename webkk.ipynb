# %%
##pip install bs4

# %%
##pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=vivo+mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=vivo+mobiles%7CMobiles&requestId=81f8c07e-1de3-4b21-ac0e-3db332d1be8f&as-searchtext=vivo"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
name=soup.select("._4rR01T")

# %%
name
# Out:
# [<div class="_4rR01T">vivo V19 (Mystic Silver, 128 GB)</div>,
#  <div class="_4rR01T">vivo V19 (Mystic Silver, 256 GB)</div>,
#  <div class="_4rR01T">vivo V19 (Piano Black, 256 GB)</div>,
#  <div class="_4rR01T">vivo Y81 (Black, 32 GB)</div>,
#  <div class="_4rR01T">vivo V11 Pro (Starry Night Black, 64 GB)</div>,
#  <div class="_4rR01T">vivo V15 Pro (Ruby Red, 128 GB)</div>,
#  <div class="_4rR01T">vivo V15 (Frozen Black, 64 GB)</div>,
#  <div class="_4rR01T">vivo V15 Pro (Topaz Blue, 128 GB)</div>,
#  <div class="_4rR01T">vivo Y91 (Starry Black, 32 GB)</div>,
#  <div class="_4rR01T">vivo Z1Pro (Sonic Black, 64 GB)</div>,
#  <div class="_4rR01T">vivo Z1Pro (Sonic Blue, 64 GB)</div>,
#  <div class="_4rR01T">vivo Z1Pro (Sonic Blue, 64 GB)</div>,
#  <div class="_4rR01T">vivo U10 (Thunder Black, 32 GB)</div>,
#  <div class="_4rR01T">vivo V17 (Midnight Ocean Black, 128 GB)</div>,
#  <div class="_4rR01T">vivo V17 (Glacier ice white, 128 GB)</div>,
# ...

# %%
price=soup.select("._1_WHN1")

# %%
price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹25,049</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹32,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹28,549</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,849</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,599</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,049</div>,
#  <div class="_30jeq3 _1_WHN1">₹39,000</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹29,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹34,990</div>,
# ...

# %%
import pandas

# %%
mobile=pandas.DataFrame(name,columns=["mobile name"])

# %%
mobile
# Out:
#                                  mobile name
# 0           vivo V19 (Mystic Silver, 128 GB)
# 1           vivo V19 (Mystic Silver, 256 GB)
# 2             vivo V19 (Piano Black, 256 GB)
# 3                    vivo Y81 (Black, 32 GB)
# 4   vivo V11 Pro (Starry Night Black, 64 GB)
# 5            vivo V15 Pro (Ruby Red, 128 GB)
# 6             vivo V15 (Frozen Black, 64 GB)
# 7          vivo V15 Pro (Topaz Blue, 128 GB)
# 8             vivo Y91 (Starry Black, 32 GB)
# 9            vivo Z1Pro (Sonic Black, 64 GB)
# 10            vivo Z1Pro (Sonic Blue, 64 GB)
# 11            vivo Z1Pro (Sonic Blue, 64 GB)
# 12           vivo U10 (Thunder Black, 32 GB)
# 13   vivo V17 (Midnight Ocean Black, 128 GB)
# 14      vivo V17 (Glacier ice white, 128 GB)
# 15            vivo V19 (Piano Black, 128 GB)
# 16           vivo V21 5G (Dusk Blue, 256 GB)
# 17    vivo Y20G 2021 (Obsidian Black, 64 GB)
# 18       vivo Y20G 2021 (Purist Blue, 64 GB)
# 19       vivo V23 5G (Sunshine Gold, 128 GB)
# ...

# %%
url="https://www.flipkart.com/search?q=men+shoesin+addidas&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=on&as=off&as-pos=2&as-type=HISTORY"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
name=soup.select("._1W9f5C div")

# %%
name
# Out:
# [<div>1. ADIDAS Court Rage M Running...</div>,
#  <div>2. ADIDAS Crihase Cricket Shoe...</div>,
#  <div>3. ADIDAS Adistound M Running ...</div>,
#  <div>4. Bonsar 0260 Slip On For Men</div>,
#  <div>5. ADIDAS Dasherr M Running Sh...</div>]

# %%
price=soup.select(".UMT9wN")

# %%
price
# Out:
# [<div class="_30jeq3 UMT9wN">₹1,645</div>,
#  <div class="_30jeq3 UMT9wN">₹1,999</div>,
#  <div class="_30jeq3 UMT9wN">₹1,047</div>,
#  <div class="_30jeq3 UMT9wN">₹474</div>,
#  <div class="_30jeq3 UMT9wN">₹2,063</div>]

# %%
rating=soup.select("._3VDxyD ._3LWZlK")

# %%
rating
# Out:
# [<div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>]

# %%
offer=soup.select("._2FuKQX span")

# %%
offer
# Out:
# [<span>64% off</span>,
#  <span>50% off</span>,
#  <span>61% off</span>,
#  <span>52% off</span>,
#  <span>57% off</span>]
